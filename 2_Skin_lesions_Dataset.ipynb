# %% [markdown]
# # Create directory with image dataset

# %% [markdown]
# ## This notebook contains code to put images into directory structure which will allow to use Keras ImageDataGenerator.

# %%
import pandas as pd
import os
from shutil import copyfile

# %%
#Load the dataframe with information for 
df=pd.read_csv('2classes_df.csv')

# %%
df
# Out:
#         lesion_id               image_id   dx dx_type   age     sex  \
# 0     HAM_0001396           ISIC_0025276  bkl   histo  55.0  female
# 1     HAM_0007207           ISIC_0031326  bkl   histo  65.0    male
# 2     HAM_0006071           ISIC_0032343  bkl   histo  70.0  female
# 3     HAM_0005612           ISIC_0024981  bkl   histo  80.0    male
# 4     HAM_0005388           ISIC_0027815  bkl   histo  80.0    male
# ...           ...                    ...  ...     ...   ...     ...
# 8116          944    PAT_498_944_488.png  NaN     NaN  60.0  FEMALE
# 8117          822    PAT_414_822_420.png  NaN     NaN  20.0  FEMALE
# 8118          785    PAT_386_785_536.png  NaN     NaN  66.0    MALE
# 8119          421    PAT_273_421_905.png  NaN     NaN  41.0    MALE
# 8120         3156  PAT_1708_3156_175.png  NaN     NaN  73.0     NaN
#
#      localization  duplicate  class  cancerous    set
# 0           trunk          0      2          0  train
# ...

# %%
df.groupby(['set'], as_index=False).count()
# Out:
#      set  lesion_id  image_id    dx  dx_type   age   sex  localization  \
# 0   test        812       812   595      595   810   760           812
# 1  train       6090      6090  5401     5401  6047  5892          6090
# 2    val       1219      1219   916      916  1215  1119          1219
#
#    duplicate  class  cancerous
# 0        812    812        812
# 1       6090   6090       6090
# 2       1219   1219       1219

# %%
#Uncomment the cell if you would like to create the directories
"""
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/0_Non_Cancerous/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/1_Cancerous/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/0_Non_Cancerous/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/1_Cancerous/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/0_Non_Cancerous/')
os.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/1_Cancerous/')
"""
# Out:
# "\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/0_Non_Cancerous/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/1_Cancerous/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/0_Non_Cancerous/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/1_Cancerous/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/0_Non_Cancerous/')\nos.mkdir('C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/1_Cancerous/')\n"

# %%
orig_folder= 'C:/Users/kravc/Final_Project/Data/Skin_classifier/lesion_images/'
train_folder = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/'
val_folder = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/'
test_folder = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/'
train_0 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/0_Non_Cancerous'
train_1 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/training/1_Cancerous'
val_0 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/0_Non_Cancerous'
val_1 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/validation/1_Cancerous'
test_0 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/0_Non_Cancerous'
test_1 = 'C:/Users/kravc/Final_Project/Data/Skin_classifier/skin_2cl/test/1_Cancerous'

# %%
#Copy images into respective folders to use with Keras flow_from_directory ImageDataGenerator

image_ids = df['image_id'].tolist()
subsets = df['set'].tolist()
labels = df['cancerous'].tolist()

for index, image in enumerate(image_ids):
    image = image + '.jpg'
    if subsets[index] == 'train':
        if labels[index] == 0:
            copyfile(os.path.join(orig_folder, image), os.path.join(train_0, image))
        elif labels[index] == 1:
            copyfile(os.path.join(orig_folder, image), os.path.join(train_1, image))
    elif subsets[index] == 'val':
        if labels[index] == 0:
            copyfile(os.path.join(orig_folder, image), os.path.join(val_0, image))
        elif labels[index] == 1:
            copyfile(os.path.join(orig_folder, image), os.path.join(val_1, image))
    elif subsets[index] == 'test':
        if labels[index] == 0:
            copyfile(os.path.join(orig_folder, image), os.path.join(test_0, image))
        elif labels[index] == 1:
            copyfile(os.path.join(orig_folder, image), os.path.join(test_1, image))

# %% [markdown]
# ## Now we have the images directory of the following structure:

# %%
"""
skin_2cl
├───test
│   ├───0_Non_Cancerous
│   └───1_Cancerous
├───training
│   ├───0_Non_Cancerous
│   └───1_Cancerous
└───validation
    ├───0_Non_Cancerous
    └───1_Cancerous
"""
# Out:
# '\nskin_2cl\n├───test\n│   ├───0_Non_Cancerous\n│   └───1_Cancerous\n├───training\n│   ├───0_Non_Cancerous\n│   └───1_Cancerous\n└───validation\n    ├───0_Non_Cancerous\n    └───1_Cancerous\n'
